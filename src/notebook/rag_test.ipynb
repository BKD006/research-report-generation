# %%
import sys, os

# Get project root — one level up from "research-report-generation"
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_root)

print("Project root added to path:", project_root)
# Out:
# Project root added to path: c:\Users\birok\Python\LLMOPs\research-report-generation

# %%
from src.api.retriever.chunking import DocumentChunker
from src.api.retriever.vectorstore import VectorStoreManager
from src.api.retriever.embedding import EmbeddingService
from src.api.retriever.ingestion import DocumentIngestor

# %%
ingestor = DocumentIngestor()

docs = ingestor.ingest_files([
    r"C:\Users\birok\Python\LLMOPs\research-report-generation\temp_uploads\Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf",
    r"C:\Users\birok\Python\LLMOPs\research-report-generation\temp_uploads\Design Document – Internal Ml Research Copilot.pdf",
    r"C:\Users\birok\Python\LLMOPs\research-report-generation\temp_uploads\Internal Research Notes – Evaluation Of Retrieval-augmented Multi-agent Systems.pdf",
    r"C:\Users\birok\Python\LLMOPs\research-report-generation\temp_uploads\Internal Ticket – Mlplat-2478 Gpu Training Instability.pdf",
    r"C:\Users\birok\Python\LLMOPs\research-report-generation\temp_uploads\Postmortem – Gpu Training Pipeline Outage (sev-2).pdf",
    r"C:\Users\birok\Python\LLMOPs\research-report-generation\temp_uploads\Rfc-012 – Deprecation Of Tensor Flow Training Pipelines.pdf"
])

print("Total documents loaded:", len(docs))
print(docs[0].metadata)
print(docs[0].page_content[:300])
# Out:
# ✅ Loaded 4 Document objects from Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf
# ✅ Loaded 5 Document objects from Design Document – Internal Ml Research Copilot.pdf
# ✅ Loaded 4 Document objects from Internal Research Notes – Evaluation Of Retrieval-augmented Multi-agent Systems.pdf
# ✅ Loaded 3 Document objects from Internal Ticket – Mlplat-2478 Gpu Training Instability.pdf
# ✅ Loaded 4 Document objects from Postmortem – Gpu Training Pipeline Outage (sev-2).pdf
# ✅ Loaded 4 Document objects from Rfc-012 – Deprecation Of Tensor Flow Training Pipelines.pdf
#
# ✅ Total loaded documents: 24
# Total documents loaded: 24
# {'producer': 'WeasyPrint 65.1', 'creator': 'ChatGPT', 'creationdate': '', 'title': 'Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System', 'author': 'ChatGPT Canvas', 'source': 'C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\temp_uploads\\Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1', 'file_name': 'Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf', 'file_type': '.pdf'}
# ADR-021: Adoption of a Retrieval-Augmented
# Multi-Agent Research System
# Status: Accepted
# Date: 2026-01-08
# Deciders: AI Platform Lead, ML Infrastructure Lead, Research Director
# Technical Story: Internal Research Enablement
# 1. Context
# The organization relies heavily on internal technical knowledge to m

# %%
chunker = DocumentChunker()
chunks = chunker.chunk(docs)
print("✅ Total Docs Loaded:", len(docs))
print("✅ Total Chunks:", len(chunks))

# Preview first chunk
print("\n--- First Chunk Preview ---")
print(chunks[0].page_content[:300])
print("\n--- First Chunk Metadata ---")
print(chunks[0].metadata)
# Out:
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:01.947447Z", "level": "info", "event": "Configuration loaded successfully"}
# {"module": "DocumentChunker", "timestamp": "2026-01-11T13:26:01.953906Z", "level": "info", "event": "Chunked 24 documents into 79 chunks."}
# ✅ Total Docs Loaded: 24
# ✅ Total Chunks: 79
#
# --- First Chunk Preview ---
# ADR-021: Adoption of a Retrieval-Augmented
# Multi-Agent Research System
# Status: Accepted
# Date: 2026-01-08
# Deciders: AI Platform Lead, ML Infrastructure Lead, Research Director
# Technical Story: Internal Research Enablement
# 1. Context
# The organization relies heavily on internal technical knowledge to m
#
# --- First Chunk Metadata ---
# {'producer': 'WeasyPrint 65.1', 'creator': 'ChatGPT', 'creationdate': '', 'title': 'Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System', 'author': 'ChatGPT Canvas', 'source': 'C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\temp_uploads\\Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1', 'file_name': 'Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf', 'file_type': '.pdf', 'chunk_id': 0, 'total_chunks': 4}

# %%
from collections import defaultdict

chunks_per_pdf = defaultdict(list)

for c in chunks:
    source = c.metadata.get("source", "")
    
    # ✅ filter: only chunks coming from temp_uploads folder
    if "temp_uploads" in source.replace("\\", "/"):
        pdf_name = c.metadata.get("file_name") or "unknown"
        chunks_per_pdf[pdf_name].append(c)

print("✅ Chunks per PDF (temp_uploads only):\n")

for pdf_name, pdf_chunks in sorted(chunks_per_pdf.items(), key=lambda x: len(x[1]), reverse=True):
    print(f"- {pdf_name}: {len(pdf_chunks)} chunks")
# Out:
# ✅ Chunks per PDF (temp_uploads only):
#
# - Design Document – Internal Ml Research Copilot.pdf: 16 chunks
# - Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf: 14 chunks
# - Internal Research Notes – Evaluation Of Retrieval-augmented Multi-agent Systems.pdf: 14 chunks
# - Postmortem – Gpu Training Pipeline Outage (sev-2).pdf: 13 chunks
# - Rfc-012 – Deprecation Of Tensor Flow Training Pipelines.pdf: 12 chunks
# - Internal Ticket – Mlplat-2478 Gpu Training Instability.pdf: 10 chunks

# %%
pages_per_pdf = defaultdict(set)

for d in docs:
    source = d.metadata.get("source", "")
    if "temp_uploads" in source.replace("\\", "/"):
        pdf_name = d.metadata.get("file_name") or "unknown"
        page = d.metadata.get("page")
        if page is not None:
            pages_per_pdf[pdf_name].add(page)

print("\n✅ Pages per PDF (temp_uploads only):\n")
for pdf_name, pages in sorted(pages_per_pdf.items(), key=lambda x: len(x[1]), reverse=True):
    print(f"- {pdf_name}: {len(pages)} pages")
# Out:
# ✅ Pages per PDF (temp_uploads only):
#
# - Design Document – Internal Ml Research Copilot.pdf: 5 pages
# - Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf: 4 pages
# - Internal Research Notes – Evaluation Of Retrieval-augmented Multi-agent Systems.pdf: 4 pages
# - Postmortem – Gpu Training Pipeline Outage (sev-2).pdf: 4 pages
# - Rfc-012 – Deprecation Of Tensor Flow Training Pipelines.pdf: 4 pages
# - Internal Ticket – Mlplat-2478 Gpu Training Instability.pdf: 3 pages

# %%
from src.api.retriever.embedding import EmbeddingService

embedding_service = EmbeddingService()

embeddings = embedding_service.embed_documents(chunks)

print("Total chunks:", len(chunks))
print("Total embeddings:", len(embeddings))
print("Embedding dimension:", len(embeddings[0]))
# Out:
# {"timestamp": "2026-01-11T13:26:05.750133Z", "level": "info", "event": "GROQ_API_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:05.750133Z", "level": "info", "event": "AWS_SECRET_ACCESS_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:05.754242Z", "level": "info", "event": "AWS_ACCESS_KEY_ID loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:05.756443Z", "level": "info", "event": "AWS_DEFAULT_REGION loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:05.757845Z", "level": "info", "event": "OPENAI_API_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:05.757845Z", "level": "info", "event": "OPENAI_ENDPOINT loaded successfully from environment"}
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:05.764805Z", "level": "info", "event": "Configuration loaded successfully"}
# {"config_keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:05.764805Z", "level": "info", "event": "YAML config loaded"}
# {"model": "amazon.titan-embed-text-v2:0", "timestamp": "2026-01-11T13:26:05.764805Z", "level": "info", "event": "Load embedding model"}
# {"model": "amazon.titan-embed-text-v2:0", "timestamp": "2026-01-11T13:26:05.841444Z", "level": "info", "event": "Embedding model loaded successfully"}
# {"module": "EmbeddingService", "timestamp": "2026-01-11T13:26:05.841444Z", "level": "info", "event": "Embedding model loaded."}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': 'fc7dc969-d22c-466e-9a64-a3940400fc92', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:26:06 GMT', 'content-type': 'application/json', 'content-length': '43297', 'connection': 'keep-alive', 'x-amzn-requestid': 'fc7dc969-d22c-466e-9a64-a3940400fc92', 'x-amzn-bedrock-invocation-latency': '82', 'x-amzn-bedrock-input-token-count': '89'}, 'RetryAttempts': 0}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': 'a067d867-10fa-4f25-9d2b-2e70b9ab7369', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:26:07 GMT', 'content-type': 'application/json', 'content-length': '43395', 'connection': 'keep-alive', 'x-amzn-requestid': 'a067d867-10fa-4f25-9d2b-2e70b9ab7369', 'x-amzn-bedrock-invocation-latency': '86', 'x-amzn-bedrock-input-token-count': '80'}, 'RetryAttempts': 0}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': 'd7e62870-81ab-4b30-8e17-924f21498cde', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:26:07 GMT', 'content-type': 'application/json', 'content-length': '43398', 'connection': 'keep-alive', 'x-amzn-requestid': 'd7e62870-81ab-4b30-8e17-924f21498cde', 'x-amzn-bedrock-invocation-latency': '106', 'x-amzn-bedrock-input-token-count': '100'}, 'RetryAttempts': 0}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': '3a4f97d2-c247-4330-bc10-01b80d1667e6', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:26:08 GMT', 'content-type': 'application/json', 'content-length': '43355', 'connection': 'keep-alive', 'x-amzn-requestid': '3a4f97d2-c247-4330-bc10-01b80d1667e6', 'x-amzn-bedrock-invocation-latency': '76', 'x-amzn-bedrock-input-token-count': '82'}, 'RetryAttempts': 0}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': '34793e5f-c8ca-412c-8d1c-14e0e57bfeca', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:26:08 GMT', 'content-type': 'application/json', 'content-length': '43345', 'connection': 'keep-alive', 'x-amzn-requestid': '34793e5f-c8ca-412c-8d1c-14e0e57bfeca', 'x-amzn-bedrock-invocation-latency': '78', 'x-amzn-bedrock-input-token-count': '79'}, 'RetryAttempts': 0}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': '96583a35-4801-49ad-aa27-5a7c7b74fb5a', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:26:09 GMT', 'content-type': 'application/json', 'content-length': '43408', 'connection': 'keep-alive', 'x-amzn-requestid': '96583a35-4801-49ad-aa27-5a7c7b74fb5a', 'x-amzn-bedrock-invocation-latency': '89', 'x-amzn-bedrock-input-token-count': '100'}, 'RetryAttempts': 0}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': '81a1e394-3c31-4765-a5e0-a7cdcd19e3fc', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:26
 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:26:35 GMT', 'content-type': 'application/json', 'content-length': '43351', 'connection': 'keep-alive', 'x-amzn-requestid': '21cacaed-584b-4358-a269-555a8ff7178d', 'x-amzn-bedrock-invocation-latency': '80', 'x-amzn-bedrock-input-token-count': '50'}, 'RetryAttempts': 0}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': '61bb0268-3152-41a1-af75-e2609e8644f0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:26:35 GMT', 'content-type': 'application/json', 'content-length': '43305', 'connection': 'keep-alive', 'x-amzn-requestid': '61bb0268-3152-41a1-af75-e2609e8644f0', 'x-amzn-bedrock-invocation-latency': '77', 'x-amzn-bedrock-input-token-count': '93'}, 'RetryAttempts': 0}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': 'db72f8e5-e098-4b98-9f18-b7bf9c272ce0', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:26:36 GMT', 'content-type': 'application/json', 'content-length': '43400', 'connection': 'keep-alive', 'x-amzn-requestid': 'db72f8e5-e098-4b98-9f18-b7bf9c272ce0', 'x-amzn-bedrock-invocation-latency': '88', 'x-amzn-bedrock-input-token-count': '114'}, 'RetryAttempts': 0}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': '05b198b9-8196-484b-93fd-48ef7d930374', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:26:36 GMT', 'content-type': 'application/json', 'content-length': '43369', 'connection': 'keep-alive', 'x-amzn-requestid': '05b198b9-8196-484b-93fd-48ef7d930374', 'x-amzn-bedrock-invocation-latency': '71', 'x-amzn-bedrock-input-token-count': '99'}, 'RetryAttempts': 0}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': 'a37d497c-8911-46a5-96af-cb0b32de02e4', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:26:36 GMT', 'content-type': 'application/json', 'content-length': '43385', 'connection': 'keep-alive', 'x-amzn-requestid': 'a37d497c-8911-46a5-96af-cb0b32de02e4', 'x-amzn-bedrock-invocation-latency': '54', 'x-amzn-bedrock-input-token-count': '55'}, 'RetryAttempts': 0}
# Total chunks: 79
# Total embeddings: 79
# Embedding dimension: 1024

# %%
from src.api.retriever.vectorstore import VectorStoreManager

vs_manager = VectorStoreManager()

vectorstore = vs_manager.add_documents_with_embeddings(
    documents=chunks,
    embeddings=embeddings
)

print("✅ Stored chunks into FAISS.")
print("Vectorstore type:", type(vectorstore))
# Out:
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:41.608748Z", "level": "info", "event": "Configuration loaded successfully"}
# {"timestamp": "2026-01-11T13:26:41.618798Z", "level": "info", "event": "GROQ_API_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:41.620832Z", "level": "info", "event": "AWS_SECRET_ACCESS_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:41.620832Z", "level": "info", "event": "AWS_ACCESS_KEY_ID loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:41.624615Z", "level": "info", "event": "AWS_DEFAULT_REGION loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:41.625950Z", "level": "info", "event": "OPENAI_API_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:41.625950Z", "level": "info", "event": "OPENAI_ENDPOINT loaded successfully from environment"}
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:41.631939Z", "level": "info", "event": "Configuration loaded successfully"}
# {"config_keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:41.634368Z", "level": "info", "event": "YAML config loaded"}
# {"model": "amazon.titan-embed-text-v2:0", "timestamp": "2026-01-11T13:26:41.634368Z", "level": "info", "event": "Load embedding model"}
# {"model": "amazon.titan-embed-text-v2:0", "timestamp": "2026-01-11T13:26:41.725250Z", "level": "info", "event": "Embedding model loaded successfully"}
# {"module": "VectorStoreManager", "timestamp": "2026-01-11T13:26:41.725250Z", "level": "info", "event": "Loading existing FAISS vectorstore from ./faiss_db"}
# Loading faiss with AVX2 support.
# Successfully loaded faiss with AVX2 support.
# {"module": "VectorStoreManager", "timestamp": "2026-01-11T13:26:41.761645Z", "level": "info", "event": "Deduplication enabled. Adding 79 new chunks."}
# {"module": "VectorStoreManager", "timestamp": "2026-01-11T13:26:41.761645Z", "level": "info", "event": "Appending embeddings to existing FAISS index."}
# {"module": "VectorStoreManager", "timestamp": "2026-01-11T13:26:41.780277Z", "level": "info", "event": "FAISS vectorstore persisted."}
# {"module": "VectorStoreManager", "timestamp": "2026-01-11T13:26:41.780277Z", "level": "info", "event": "Added 79 embedded chunks to FAISS."}
# ✅ Stored chunks into FAISS.
# Vectorstore type: <class 'langchain_community.vectorstores.faiss.FAISS'>

# %%
# 1) Your test retrieval query
query = "What are the goals and non-goals of the Internal ML Research Copilot?"

# 2) Create a retriever from your vectorstore
retriever = vectorstore.as_retriever(search_kwargs={"k": 5})

# 3) Retrieve top-k chunks
results = retriever.invoke(query)

# 4) Print results
print(f"Retrieved {len(results)} chunks\n")

for i, doc in enumerate(results, start=1):
    print("=" * 80)
    print(f"Result {i}")
    print("File:", doc.metadata.get("file_name"))
    print("Chunk ID:", doc.metadata.get("chunk_id"))
    print(doc.page_content[:500])
    print()
# Out:
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': 'eadb1742-f3b1-4bf4-ac88-78115a6c72cf', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 12:32:58 GMT', 'content-type': 'application/json', 'content-length': '43303', 'connection': 'keep-alive', 'x-amzn-requestid': 'eadb1742-f3b1-4bf4-ac88-78115a6c72cf', 'x-amzn-bedrock-invocation-latency': '75', 'x-amzn-bedrock-input-token-count': '17'}, 'RetryAttempts': 0}
# Retrieved 5 chunks
#
# ================================================================================
# Result 1
# File: Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf
# Chunk ID: 0
# ADR-021: Adoption of a Retrieval-Augmented
# Multi-Agent Research System
# Status: Accepted
# Date: 2026-01-08
# Deciders: AI Platform Lead, ML Infrastructure Lead, Research Director
# Technical Story: Internal Research Enablement
# 1. Context
# The organization relies heavily on internal technical knowledge to make architecture, infrastructure, and
# research decisions. This knowledge is distributed across multiple formats and systems, including design
# documents, architecture decision records (ADRs), RFCs, pos
#
# ================================================================================
# Result 2
# File: Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf
# Chunk ID: 0
# Cons: -  Higher  implementation  complexity  -  Requires  careful  prompt  and  workflow  design  -  Initial
# operational overhead
# 5. Decision
# The  organization  will  adopt  a  retrieval-augmented,  multi-agent  research  system as  the  primary
# approach for internal technical research and decision support.
# The system will: - Use semantic retrieval over approved internal documents - Employ multiple analyst agents
# representing different technical perspectives - Orchestrate reasoning and synthesis
#
# ================================================================================
# Result 3
# File: Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf
# Chunk ID: 1
# synthesis by engineers and researchers.
# Pros: - No new infrastructure required - Familiar workflow for teams
# Cons: - Poor semantic understanding - High manual effort - Does not scale with document volume - No
# structured synthesis
# Option 2: Single-Agent LLM with Retrieval (Basic RAG)
# Description: Deploy a single LLM-based assistant augmented with retrieval over internal documents.
# Pros: - Improved grounding compared to pure LLM usage - Relatively simple implementation
# Cons: -  Limited  reasoning
#
# ================================================================================
# Result 4
# File: Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf
# Chunk ID: 1
# decisions - Understanding the rationale behind past architectural choices - Synthesizing information across
# documents and time periods - Onboarding new engineers and researchers efficiently
# Existing  solutions  include  keyword-based  search,  manual  document  reviews,  and  ad-hoc  use  of  large
# language models (LLMs). However , these approaches have proven insufficient for complex research and
# decision-support tasks. Keyword search lacks semantic understanding, while generic LLM usage introd
#
# ================================================================================
# Result 5
# File: Adr-021 – Adoption Of Retrieval-augmented Multi-agent Research System.pdf
# Chunk ID: 2
# Option 3: Retrieval-Augmented Multi-Agent Research System (Selected)
# Description: Adopt  a  system  that  combines:  -  Retrieval-augmented  generation  (RAG)  over  internal
# documents - Multiple analyst agents with domain-specific roles - Structured workflow orchestration using a
# state machine - Human-in-the-loop controls
# Pros: - Deep, multi-perspective reasoning - Strong grounding in internal evidence - Clear traceability of
# conclusions - Supports complex research and decision workflows
# •
# •

# %%
from src.api.retriever.retriever import SimpleRAGRetriever, SimpleRAGRetrieverWithMMR, SimpleRAGRetrieverWithThreshold
query = "What are the goals and non-goals of the Internal ML Research Copilot?"

# %%
retreiver1 = SimpleRAGRetriever(top_k=3)
retreiver2 = SimpleRAGRetrieverWithMMR(top_k=2)
retreiver3 = SimpleRAGRetrieverWithThreshold(top_k=2)
# Out:
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:56.235507Z", "level": "info", "event": "Configuration loaded successfully"}
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:56.243199Z", "level": "info", "event": "Configuration loaded successfully"}
# {"timestamp": "2026-01-11T13:26:56.246075Z", "level": "info", "event": "GROQ_API_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.246075Z", "level": "info", "event": "AWS_SECRET_ACCESS_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.246075Z", "level": "info", "event": "AWS_ACCESS_KEY_ID loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.246075Z", "level": "info", "event": "AWS_DEFAULT_REGION loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.246075Z", "level": "info", "event": "OPENAI_API_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.246075Z", "level": "info", "event": "OPENAI_ENDPOINT loaded successfully from environment"}
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:56.246075Z", "level": "info", "event": "Configuration loaded successfully"}
# {"config_keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:56.258071Z", "level": "info", "event": "YAML config loaded"}
# {"model": "amazon.titan-embed-text-v2:0", "timestamp": "2026-01-11T13:26:56.258071Z", "level": "info", "event": "Load embedding model"}
# {"model": "amazon.titan-embed-text-v2:0", "timestamp": "2026-01-11T13:26:56.337489Z", "level": "info", "event": "Embedding model loaded successfully"}
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:56.341318Z", "level": "info", "event": "Configuration loaded successfully"}
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:56.343069Z", "level": "info", "event": "Configuration loaded successfully"}
# {"timestamp": "2026-01-11T13:26:56.343069Z", "level": "info", "event": "GROQ_API_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.343069Z", "level": "info", "event": "AWS_SECRET_ACCESS_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.343069Z", "level": "info", "event": "AWS_ACCESS_KEY_ID loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.343069Z", "level": "info", "event": "AWS_DEFAULT_REGION loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.343069Z", "level": "info", "event": "OPENAI_API_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.343069Z", "level": "info", "event": "OPENAI_ENDPOINT loaded successfully from environment"}
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:56.343069Z", "level": "info", "event": "Configuration loaded successfully"}
# {"config_keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:56.343069Z", "level": "info", "event": "YAML config loaded"}
# {"model": "amazon.titan-embed-text-v2:0", "timestamp": "2026-01-11T13:26:56.343069Z", "level": "info", "event": "Load embedding model"}
# {"model": "amazon.titan-embed-text-v2:0", "timestamp": "2026-01-11T13:26:56.442067Z", "level": "info", "event": "Embedding model loaded successfully"}
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:56.442067Z", "level": "info", "event": "Configuration loaded successfully"}
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:56.453252Z", "level": "info", "event": "Configuration loaded successfully"}
# {"timestamp": "2026-01-11T13:26:56.453252Z", "level": "info", "event": "GROQ_API_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.458443Z", "level": "info", "event": "AWS_SECRET_ACCESS_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.458443Z", "level": "info", "event": "AWS_ACCESS_KEY_ID loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.458443Z", "level": "info", "event": "AWS_DEFAULT_REGION loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.458443Z", "level": "info", "event": "OPENAI_API_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:26:56.463712Z", "level": "info", "event": "OPENAI_ENDPOINT loaded successfully from environment"}
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:56.466547Z", "level": "info", "event": "Configuration loaded successfully"}
# {"config_keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:26:56.466547Z", "level": "info", "event": "YAML config loaded"}
# {"model": "amazon.titan-embed-text-v2:0", "timestamp": "2026-01-11T13:26:56.466547Z", "level": "info", "event": "Load embedding model"}
# {"model": "amazon.titan-embed-text-v2:0", "timestamp": "2026-01-11T13:26:56.579781Z", "level": "info", "event": "Embedding model loaded successfully"}

# %%
retreiver1.retrieve(query)
# Out:
# {"module": "VectorStoreManager", "timestamp": "2026-01-11T13:27:00.341682Z", "level": "info", "event": "Loading existing FAISS vectorstore from ./faiss_db"}
# {"module": "AutonomousReportGenerator", "timestamp": "2026-01-11T13:27:00.346186Z", "level": "info", "event": "Simple similarity retriever initialized."}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': 'a63b446b-9454-4909-a442-6f5c1026f271', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:27:01 GMT', 'content-type': 'application/json', 'content-length': '43303', 'connection': 'keep-alive', 'x-amzn-requestid': 'a63b446b-9454-4909-a442-6f5c1026f271', 'x-amzn-bedrock-invocation-latency': '75', 'x-amzn-bedrock-input-token-count': '17'}, 'RetryAttempts': 0}
# [Document(id='Design Document – Internal Ml Research Copilot.pdf::p0::c0::c0280f71f1cc', metadata={'producer': 'WeasyPrint 65.1', 'creator': 'ChatGPT', 'creationdate': '', 'title': 'Design Document – Internal Ml Research Copilot', 'author': 'ChatGPT Canvas', 'source': 'C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\temp_uploads\\Design Document – Internal Ml Research Copilot.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'file_name': 'Design Document – Internal Ml Research Copilot.pdf', 'file_type': '.pdf', 'chunk_id': 0, 'total_chunks': 4, 'chunk_uid': 'Design Document – Internal Ml Research Copilot.pdf::p0::c0::c0280f71f1cc'}, page_content='Design Document: Internal ML Research Copilot\nAuthor: AI Platform Team\nDate: 2026-01-08\nStatus: Draft\n1. Overview\nThe  Internal  ML  Research  Copilot is  a  retrieval-augmented,  multi-agent  AI  system  designed  to  help\nengineers,  researchers,  and  technical  leaders  answer  complex,  organization-specific  questions  using\ninternal knowledge sources. Unlike traditional chatbots or search tools, this system simulates a panel of'),
#  Document(id='Design Document – Internal Ml Research Copilot.pdf::p3::c2::43171a88a785', metadata={'producer': 'WeasyPrint 65.1', 'creator': 'ChatGPT', 'creationdate': '', 'title': 'Design Document – Internal Ml Research Copilot', 'author': 'ChatGPT Canvas', 'source': 'C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\temp_uploads\\Design Document – Internal Ml Research Copilot.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'file_name': 'Design Document – Internal Ml Research Copilot.pdf', 'file_type': '.pdf', 'chunk_id': 2, 'total_chunks': 3, 'chunk_uid': 'Design Document – Internal Ml Research Copilot.pdf::p3::c2::43171a88a785'}, page_content='Feedback-based ranking of documents\nIntegration with issue trackers and CI systems\n11. Summary\nThe Internal ML Research Copilot provides a scalable, trustworthy way to reason over internal technical\nknowledge using retrieval-augmented, multi-agent AI workflows. By combining structured orchestration,\n• \n• \n• \n• \n• \n• \n• \n• \n• \n• \n4'),
#  Document(id='Design Document – Internal Ml Research Copilot.pdf::p0::c3::f103e970f5d2', metadata={'producer': 'WeasyPrint 65.1', 'creator': 'ChatGPT', 'creationdate': '', 'title': 'Design Document – Internal Ml Research Copilot', 'author': 'ChatGPT Canvas', 'source': 'C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\temp_uploads\\Design Document – Internal Ml Research Copilot.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'file_name': 'Design Document – Internal Ml Research Copilot.pdf', 'file_type': '.pdf', 'chunk_id': 3, 'total_chunks': 4, 'chunk_uid': 'Design Document – Internal Ml Research Copilot.pdf::p0::c3::f103e970f5d2'}, page_content='Underutilized in decision-making\nExisting solutions such as keyword search or generic LLM chatbots fail to capture cross-document context,\nhistorical decisions, and nuanced trade-offs. This leads to repeated work, loss of institutional memory, and\ndecisions that are not grounded in prior evidence.\nThe Internal ML Research Copilot addresses this gap by combining retrieval with structured multi-agent\nreasoning.\n• \n• \n• \n• \n1')]

# %%
retreiver2.retrieve(query)
# Out:
# {"module": "VectorStoreManager", "timestamp": "2026-01-11T13:27:04.899337Z", "level": "info", "event": "Loading existing FAISS vectorstore from ./faiss_db"}
# {"module": "AutonomousReportGenerator", "timestamp": "2026-01-11T13:27:04.907984Z", "level": "info", "event": "MMR retriever initialized."}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': '8fcb60ba-9e57-4744-b807-a92988c40545', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:27:05 GMT', 'content-type': 'application/json', 'content-length': '43303', 'connection': 'keep-alive', 'x-amzn-requestid': '8fcb60ba-9e57-4744-b807-a92988c40545', 'x-amzn-bedrock-invocation-latency': '85', 'x-amzn-bedrock-input-token-count': '17'}, 'RetryAttempts': 0}
# [Document(id='Design Document – Internal Ml Research Copilot.pdf::p0::c0::c0280f71f1cc', metadata={'producer': 'WeasyPrint 65.1', 'creator': 'ChatGPT', 'creationdate': '', 'title': 'Design Document – Internal Ml Research Copilot', 'author': 'ChatGPT Canvas', 'source': 'C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\temp_uploads\\Design Document – Internal Ml Research Copilot.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'file_name': 'Design Document – Internal Ml Research Copilot.pdf', 'file_type': '.pdf', 'chunk_id': 0, 'total_chunks': 4, 'chunk_uid': 'Design Document – Internal Ml Research Copilot.pdf::p0::c0::c0280f71f1cc'}, page_content='Design Document: Internal ML Research Copilot\nAuthor: AI Platform Team\nDate: 2026-01-08\nStatus: Draft\n1. Overview\nThe  Internal  ML  Research  Copilot is  a  retrieval-augmented,  multi-agent  AI  system  designed  to  help\nengineers,  researchers,  and  technical  leaders  answer  complex,  organization-specific  questions  using\ninternal knowledge sources. Unlike traditional chatbots or search tools, this system simulates a panel of'),
#  Document(id='Design Document – Internal Ml Research Copilot.pdf::p1::c0::363061316aad', metadata={'producer': 'WeasyPrint 65.1', 'creator': 'ChatGPT', 'creationdate': '', 'title': 'Design Document – Internal Ml Research Copilot', 'author': 'ChatGPT Canvas', 'source': 'C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\temp_uploads\\Design Document – Internal Ml Research Copilot.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'file_name': 'Design Document – Internal Ml Research Copilot.pdf', 'file_type': '.pdf', 'chunk_id': 0, 'total_chunks': 4, 'chunk_uid': 'Design Document – Internal Ml Research Copilot.pdf::p1::c0::363061316aad'}, page_content='3. Goals and Non-Goals\n3.1 Goals\nEnable deep, evidence-based answers to internal technical questions\nReduce time spent on manual document discovery and synthesis\nPreserve and surface institutional knowledge during decision-making\nSupport human-in-the-loop control for quality and correctness\nProvide structured outputs suitable for reports, RFCs, and presentations\n3.2 Non-Goals\nReal-time conversational support for casual queries\nAutonomous decision-making without human oversight'),
#  Document(id='Postmortem – Gpu Training Pipeline Outage (sev-2).pdf::p0::c2::dd4fc3e67b84', metadata={'producer': 'WeasyPrint 65.1', 'creator': 'ChatGPT', 'creationdate': '', 'title': 'Postmortem – Gpu Training Pipeline Outage (sev-2)', 'author': 'ChatGPT Canvas', 'source': 'C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\temp_uploads\\Postmortem – Gpu Training Pipeline Outage (sev-2).pdf', 'total_pages': 4, 'page': 0, 'page_label': '1', 'file_name': 'Postmortem – Gpu Training Pipeline Outage (sev-2).pdf', 'file_type': '.pdf', 'chunk_id': 2, 'total_chunks': 4, 'chunk_uid': 'Postmortem – Gpu Training Pipeline Outage (sev-2).pdf::p0::c2::dd4fc3e67b84'}, page_content='2. Impact\nUser Impact\nNightly retraining jobs for ranking and recommendation models failed intermittently\nApplied ML researchers experienced experiment invalidation due to partial job execution\nEngineers spent significant time manually restarting jobs and investigating failures\nBusiness Impact\nReduced model freshness for personalization features\nIncreased risk during a high-traffic business period\nLoss of engineering productivity during the incident window')]

# %%
retreiver3 = SimpleRAGRetrieverWithThreshold(top_k=2, score_threshold=0.5)
retreiver3.retrieve(query)
# Out:
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:28:19.237181Z", "level": "info", "event": "Configuration loaded successfully"}
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:28:19.241136Z", "level": "info", "event": "Configuration loaded successfully"}
# {"timestamp": "2026-01-11T13:28:19.241136Z", "level": "info", "event": "GROQ_API_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:28:19.241136Z", "level": "info", "event": "AWS_SECRET_ACCESS_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:28:19.249680Z", "level": "info", "event": "AWS_ACCESS_KEY_ID loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:28:19.250642Z", "level": "info", "event": "AWS_DEFAULT_REGION loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:28:19.253481Z", "level": "info", "event": "OPENAI_API_KEY loaded successfully from environment"}
# {"timestamp": "2026-01-11T13:28:19.253481Z", "level": "info", "event": "OPENAI_ENDPOINT loaded successfully from environment"}
# {"path": "C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\src\\config\\configuration.yaml", "keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:28:19.259403Z", "level": "info", "event": "Configuration loaded successfully"}
# {"config_keys": ["chroma", "retriever", "embedding_model", "llm"], "timestamp": "2026-01-11T13:28:19.259977Z", "level": "info", "event": "YAML config loaded"}
# {"model": "amazon.titan-embed-text-v2:0", "timestamp": "2026-01-11T13:28:19.262057Z", "level": "info", "event": "Load embedding model"}
# {"model": "amazon.titan-embed-text-v2:0", "timestamp": "2026-01-11T13:28:19.359521Z", "level": "info", "event": "Embedding model loaded successfully"}
# {"module": "VectorStoreManager", "timestamp": "2026-01-11T13:28:19.359521Z", "level": "info", "event": "Loading existing FAISS vectorstore from ./faiss_db"}
# {"module": "AutonomousReportGenerator", "timestamp": "2026-01-11T13:28:19.359521Z", "level": "info", "event": "Threshold retriever initialized (threshold=0.5)."}
# Successfully invoked model amazon.titan-embed-text-v2:0. ResponseMetadata: {'RequestId': '71ded2fc-d44c-4dd3-8618-b6bffffac913', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Sun, 11 Jan 2026 13:28:20 GMT', 'content-type': 'application/json', 'content-length': '43303', 'connection': 'keep-alive', 'x-amzn-requestid': '71ded2fc-d44c-4dd3-8618-b6bffffac913', 'x-amzn-bedrock-invocation-latency': '94', 'x-amzn-bedrock-input-token-count': '17'}, 'RetryAttempts': 0}
# [Document(id='Design Document – Internal Ml Research Copilot.pdf::p0::c0::c0280f71f1cc', metadata={'producer': 'WeasyPrint 65.1', 'creator': 'ChatGPT', 'creationdate': '', 'title': 'Design Document – Internal Ml Research Copilot', 'author': 'ChatGPT Canvas', 'source': 'C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\temp_uploads\\Design Document – Internal Ml Research Copilot.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'file_name': 'Design Document – Internal Ml Research Copilot.pdf', 'file_type': '.pdf', 'chunk_id': 0, 'total_chunks': 4, 'chunk_uid': 'Design Document – Internal Ml Research Copilot.pdf::p0::c0::c0280f71f1cc'}, page_content='Design Document: Internal ML Research Copilot\nAuthor: AI Platform Team\nDate: 2026-01-08\nStatus: Draft\n1. Overview\nThe  Internal  ML  Research  Copilot is  a  retrieval-augmented,  multi-agent  AI  system  designed  to  help\nengineers,  researchers,  and  technical  leaders  answer  complex,  organization-specific  questions  using\ninternal knowledge sources. Unlike traditional chatbots or search tools, this system simulates a panel of'),
#  Document(id='Design Document – Internal Ml Research Copilot.pdf::p3::c2::43171a88a785', metadata={'producer': 'WeasyPrint 65.1', 'creator': 'ChatGPT', 'creationdate': '', 'title': 'Design Document – Internal Ml Research Copilot', 'author': 'ChatGPT Canvas', 'source': 'C:\\Users\\birok\\Python\\LLMOPs\\research-report-generation\\temp_uploads\\Design Document – Internal Ml Research Copilot.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'file_name': 'Design Document – Internal Ml Research Copilot.pdf', 'file_type': '.pdf', 'chunk_id': 2, 'total_chunks': 3, 'chunk_uid': 'Design Document – Internal Ml Research Copilot.pdf::p3::c2::43171a88a785'}, page_content='Feedback-based ranking of documents\nIntegration with issue trackers and CI systems\n11. Summary\nThe Internal ML Research Copilot provides a scalable, trustworthy way to reason over internal technical\nknowledge using retrieval-augmented, multi-agent AI workflows. By combining structured orchestration,\n• \n• \n• \n• \n• \n• \n• \n• \n• \n• \n4')]
